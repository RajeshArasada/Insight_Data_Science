# %%
# Standard
import numpy as np
import pandas as pd

# %%
# Stats
from scipy import stats

# %%
# Plotting 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
from __future__ import division

# %%
## Load in Category Data
data05_cat= pd.read_csv('Model_Two/Categories05.csv')
data06_cat= pd.read_csv('Model_Two/Categories06.csv')
data07_cat= pd.read_csv('Model_Two/Categories07.csv')
data08_cat= pd.read_csv('Model_Two/Categories08.csv')
data09_cat= pd.read_csv('Model_Two/Categories09.csv')

#------------------------------------------------------
data10_cat= pd.read_csv('Model_Two/Categories10.csv')
data11_cat= pd.read_csv('Model_Two/Categories11.csv')
data12_cat= pd.read_csv('Model_Two/Categories12.csv')
data13_cat= pd.read_csv('Model_Two/Categories13.csv')
data14_cat= pd.read_csv('Model_Two/Categories14.csv')
data15_cat= pd.read_csv('Model_Two/Categories15.csv')

# %%
data07_cat.head()
# Out:
#    Unnamed: 0                    SubBorough  Year  Eating Place Beer  \
# 0           0                         False  2007                  7
# 1           1            Bedford Stuyvesant  2007                  0
# 2           2                   Bensonhurst  2007                  3
# 3           3                  Borough Park  2007                  5
# 4           4  Brooklyn Heights/Fort Greene  2007                  0
#
#    Vessel liquor  Restaurant liquor  Catering Establishment  \
# 0              1                  2                       0
# 1              0                  0                       0
# 2              0                  0                       1
# 3              0                  0                       0
# 4              0                  1                       0
#
#    On premise liquor  Cabaret liquor  Restaurant Wine  Tavern Wine  \
# 0                 43               0               21            1
# ...

# %%
data05_cat.ix[4,8]
# Out:
# 6.0

# %%
data14_cat['Restaurant Wine'][4]
# Out:
# 4.0

# %%
data06_cat.ix[4,8]
# Out:
# 4.0

# %%
years = pd.Series([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014])

values = pd.Series([6,4,8,2,6,9,4,7,8,4])

len(years), len(values)
# Out:
# (10, 10)

# %%
plt.figure(figsize=(8, 6), dpi=80,)

plt.plot(years,values,color = "blue",marker ='o',markersize=10,linewidth=1.0,)
plt.ticklabel_format(useOffset=False)

# %%
year_dframe = pd.concat((years,values),axis=1)
year_dframe.columns = ['Year','Values']
#year_dframe
plt.figure(figsize=(8, 6), dpi=80,)
#years = range(2005,2015,1)
ax = plt.axes()
sns.barplot(x="Year",y="Values",data=year_dframe,palette="BuPu",ax=ax)
#sns.distplot(values)#,data=year_dframe, palette="BuPu",ax=ax)
ax.set_title("Mean License Issued")
plt.xlabel('Years',fontsize=20, color='green')
plt.ylabel('Number of Liquor licenses',fontsize=20, color='green')
plt.title("Licencse Issued",fontsize=25, color='black')
plt.show()

# %%
tips = sns.load_dataset("tips")
ax = sns.regplot(x="Year", y="Values", data=year_dframe)

# Load the example planets dataset
planets = sns.load_dataset("planets")

# Make a range of years to show categories with no observations
years = np.arange(2000, 2015)

# Draw a count plot to show the number of planets discovered each year
g = sns.factorplot(x="year", data=planets, kind="count",
                   palette="BuPu", size=6, aspect=1.5, order=years)
g.set_xticklabels(step=2)

# %%
# I changed all the neighborhoods here.

data06_cat['SubBorough']
# Out:
# 0                                    False
# 1                       Bedford Stuyvesant
# 2                              Bensonhurst
# 3                             Borough Park
# 4             Brooklyn Heights/Fort Greene
# 5                                 Bushwick
# 6                             Coney Island
# 7                            East Flatbush
# 8              East New York/Starrett City
# 9                                 Flatbush
# 10                      Flatlands/Canarsie
# 11    North Crown Heights/Prospect Heights
# 12              Park Slope/Carroll Gardens
# 13    South Crown Heights/Lefferts Gardens
# 14                             Sunset Park
# 15                 Williamsburg/Greenpoint
# Name: SubBorough, dtype: object

# %%
data05_cat.ix[4,1] = data05_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data05_cat.ix[8,1] = data05_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data05_cat.ix[10,1] = data05_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data05_cat.ix[11,1] = data05_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data05_cat.ix[12,1] = data05_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data05_cat.ix[13,1] = data05_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data05_cat.ix[15,1] = data05_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data06_cat.ix[4,1] = data06_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data06_cat.ix[8,1] = data06_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data06_cat.ix[10,1] = data06_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data06_cat.ix[11,1] = data06_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data06_cat.ix[12,1] = data06_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data06_cat.ix[13,1] = data06_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data06_cat.ix[15,1] = data06_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data07_cat.ix[4,1] = data07_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data07_cat.ix[8,1] = data07_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data07_cat.ix[10,1] = data07_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data07_cat.ix[11,1] = data07_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data07_cat.ix[12,1] = data07_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data07_cat.ix[13,1] = data07_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data07_cat.ix[15,1] = data07_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data08_cat.ix[4,1] = data08_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data08_cat.ix[8,1] = data08_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data08_cat.ix[10,1] = data08_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data08_cat.ix[11,1] = data08_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data08_cat.ix[12,1] = data08_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data08_cat.ix[13,1] = data08_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data08_cat.ix[15,1] = data08_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data09_cat.ix[4,1] = data09_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data09_cat.ix[8,1] = data09_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data09_cat.ix[10,1] = data09_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data09_cat.ix[11,1] = data09_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data09_cat.ix[12,1] = data09_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data09_cat.ix[13,1] = data09_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data09_cat.ix[15,1] = data09_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data10_cat.ix[4,1] = data10_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data10_cat.ix[8,1] = data10_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data10_cat.ix[10,1] = data10_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data10_cat.ix[11,1] = data10_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data10_cat.ix[12,1] = data10_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data10_cat.ix[13,1] = data10_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data10_cat.ix[15,1] = data10_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data11_cat.ix[4,1] = data11_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data11_cat.ix[8,1] = data11_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data11_cat.ix[10,1] = data11_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data11_cat.ix[11,1] = data11_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data11_cat.ix[12,1] = data11_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data11_cat.ix[13,1] = data11_cat.ix[13,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data11_cat.ix[15,1] = data11_cat.ix[15,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data12_cat.ix[4,1] = data12_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data12_cat.ix[8,1] = data12_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data12_cat.ix[10,1] = data12_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data12_cat.ix[11,1] = data12_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data12_cat.ix[12,1] = data12_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data12_cat.ix[14,1] = data12_cat.ix[14,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data12_cat.ix[16,1] = data12_cat.ix[16,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data13_cat.ix[4,1] = data13_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data13_cat.ix[8,1] = data13_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data13_cat.ix[10,1] = data13_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data13_cat.ix[11,1] = data13_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data13_cat.ix[12,1] = data13_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data13_cat.ix[14,1] = data13_cat.ix[14,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data13_cat.ix[16,1] = data13_cat.ix[16,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data15_cat.ix[4,1] = data15_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data15_cat.ix[8,1] = data15_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data15_cat.ix[10,1] = data15_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data15_cat.ix[11,1] = data15_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data15_cat.ix[12,1] = data15_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data15_cat.ix[14,1] = data15_cat.ix[14,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data15_cat.ix[16,1] = data15_cat.ix[16,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
data14_cat.ix[4,1] = data14_cat.ix[4,1].replace('Brooklyn Heights/Fort Greene','Brooklyn Heights-Fort Greene')
data14_cat.ix[8,1] = data14_cat.ix[8,1].replace('East New York/Starrett City','East New York-Starrett City')
data14_cat.ix[10,1] = data14_cat.ix[10,1].replace('Flatlands/Canarsie','Flatlands-Canarsie')
data14_cat.ix[11,1] = data14_cat.ix[11,1].replace('North Crown Heights/Prospect Heights','North Crown Heights-Prospect Heights')
data14_cat.ix[12,1] = data14_cat.ix[12,1].replace('Park Slope/Carroll Gardens','Park Slope-Carroll Gardens')
data14_cat.ix[14,1] = data14_cat.ix[14,1].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
data14_cat.ix[16,1] = data14_cat.ix[16,1].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')

# %%
#data08_cat

# %%
data12_cat = data12_cat.drop([13])
#data12_cat.reset_index()

# %%
data13_cat = data13_cat.drop([13])
#data13_cat.reset_index()

# %%
data14_cat = data14_cat.drop([13])
#data14_cat.reset_index()

# %%
data15_cat = data15_cat.drop([13])
#data15_cat.reset_index()

# %%
data12_cat = data12_cat.reset_index()
data13_cat = data13_cat.reset_index()
data14_cat = data14_cat.reset_index()
data15_cat = data15_cat.reset_index()

# %%
#data12_cat.ix[13,2] = data12_cat.ix[13,2].replace('South Crown Heights/Lefferts Garden','South Crown Heights-Lefferts Garden')
#data12_cat.ix[15,2] = data12_cat.ix[15,2].replace('Williamsburg/Greenpoint','Williamsburg-Greenpoint')
#data12_cat

# %%
## Categories to display
#Classtype Dictionary of type of licenses

#Classtype = {141:'Eating Place Beer',240:'Vessel liquor',241:'Restaurant liquor',246:'Catering Establishment',
#                      252:'On premise liquor',341:'Restaurant Wine',344:'Tavern Wine',441:'Summer Beer',
#                      540:'Summer liquor',901:'Additional Bar',903:'Malt liquor',243:'Club Liquor',
#                      348:'Summer Tav Wine',902:'Additional Bar Two',256:'Cabaret liquor',
#                      549: 'Summer Entertainment',241:'Restaurant liquor',902:'Additional Bar Three',
#                      144:'Ball Park Beer',345:'Summer Restaurant Wine',242:'Hotel liquor',548:'Summer Food Bev',
#                      143:'Club Beer',210:'Restaurant Brewer',343:'Club Wine',354:'Wine Catering',
#                      515:'Winter Food and Bev',543:'Summer Club Liquor'}

# %%
def plot_cat(cat,city):
    # Get the index of the City
    num = list(data05_cat['SubBorough']).index(city)

    values = []

    values.append(data05_cat[cat][num])
    values.append(data06_cat[cat][num])
    values.append(data07_cat[cat][num])
    values.append(data08_cat[cat][num])
    values.append(data09_cat[cat][num])
    values.append(data10_cat[cat][num])
    values.append(data11_cat[cat][num])
    values.append(data12_cat[cat][num])
    values.append(data13_cat[cat][num])
    values.append(data14_cat[cat][num])


    values = pd.Series(values)
    years = pd.Series(range(2005,2015)) 

    year_dframe = pd.concat((years,values),axis=1)
    year_dframe.columns = ['Year','Values']

    plt.figure(figsize=(8, 6), dpi=80,)

    ax = plt.axes()
    sns.barplot(x="Year",y="Values",data=year_dframe,color="blue",ax=ax)

    #ax.set_title("Mean License Issued")
    plt.xlabel('Years',fontsize=20, color='green')
    plt.ylabel('Number of License',fontsize=20, color='green')
    plt.title(cat,fontsize=25, color='red')
    #plt.savefig('Tavern Map ' + city + '.png')
    plt.show()

# %%
neighborhoods = pd.Series(data05_cat['SubBorough'])

# %%
cat = 'Tavern Wine' #'On premise liquor' # 'Additional Bar'#'Eating Place Beer'#'Restaurant Wine'   

# Create the static pictures for my web app
for city in neighborhoods[1:]:
    plot_cat(cat,city)

# %%
years = pd.Series([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014])
values = pd.Series([6,4,8,2,6,9,4,7,8,4])
year_dframe = pd.concat((years,values),axis=1)
year_dframe.columns = ['Year','Values']
#year_dframe
plt.figure(figsize=(8, 6), dpi=80,)
#years = range(2005,2015,1)
ax = plt.axes()
sns.barplot(x="Year",y="Values",data=year_dframe,palette="BuPu",ax=ax)
data07_cat.ix[1,3:]
sns.distplot(values)#,data=year_dframe, palette="BuPu",ax=ax)
# plt.savefig('Example Map ' + city + '.png')
#plt.savefig('Today Map ' + 'Bushwick' + '.png')

# %%
plt.pie(data14_cat.ix[15,3:])
plt.ticklabel_format(useOffset=False)

# %%
data05_cat['SubBorough']
# Out:
# 0                                    False
# 1                       Bedford Stuyvesant
# 2                              Bensonhurst
# 3                             Borough Park
# 4             Brooklyn Heights-Fort Greene
# 5                                 Bushwick
# 6                             Coney Island
# 7                            East Flatbush
# 8              East New York-Starrett City
# 9                                 Flatbush
# 10                      Flatlands-Canarsie
# 11    North Crown Heights-Prospect Heights
# 12              Park Slope-Carroll Gardens
# 13    South Crown Heights-Lefferts Gardens
# 14                             Sunset Park
# 15                 Williamsburg-Greenpoint
# Name: SubBorough, dtype: object

# %%
from __future__ import print_function
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm

# %%
from statsmodels.graphics.api import qqplot

# %%
# %matplotlib inline
import os  
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import statsmodels.api as sm  
import seaborn as sb  
sb.set_style('darkgrid')

# %%
cat = 'Eating Place Beer' #'On premise liquor' # 'Additional Bar'#'Eating Place Beer'#'Restaurant Wine'   

plot_cat(cat,'Williamsburg-Greenpoint')

# %%
city = 'Williamsburg-Greenpoint'
num = list(data05_cat['SubBorough']).index(city)
cat = 'Eating Place Beer'

values = []

#values.append(data05_cat[cat][num])
#values.append(data06_cat[cat][num])
#values.append(data07_cat[cat][num])
values.append(data08_cat[cat][num])
values.append(data09_cat[cat][num])
values.append(data10_cat[cat][num])
values.append(data11_cat[cat][num])
values.append(data12_cat[cat][num])
values.append(data13_cat[cat][num])
values.append(data14_cat[cat][num])


values = pd.Series(values)
years = pd.Series(range(2008,2015)) 

year_dframe = pd.concat((years,values),axis=1)
year_dframe.columns = ['Year','Values']

# %%
plt.scatter(years,values, color = "blue", marker ='o')#,markersize=10)

# %%
year_dframe['Values'].plot(figsize=(8, 6))

# %%
year_dframe['First Difference'] = year_dframe['Values'] - year_dframe['Values'].shift()  
year_dframe['First Difference'].plot(figsize=(8, 6))

# %%
year_dframe
# Out:
#    Year  Values  First Difference
# 0  2008       1               NaN
# 1  2009       1                 0
# 2  2010       2                 1
# 3  2011       1                -1
# 4  2012       1                 0
# 5  2013       2                 1
# 6  2014       5                 3
#
# [7 rows x 3 columns]

# %%
year_dframe['Natural Log'] = year_dframe['Values'].apply(lambda x: np.log(x))  
year_dframe['Natural Log'].plot(figsize=(8, 6))

# %%
year_dframe['Original Variance'] = pd.rolling_var(year_dframe['Values'], 1,min_periods=None, freq=None, center=True)  
year_dframe['Log Variance'] = pd.rolling_var(year_dframe['Natural Log'], 1,min_periods=None, freq=None, center=True)

fig, ax = plt.subplots(2, 1, figsize=(13, 12))  
year_dframe['Original Variance'].plot(ax=ax[0], title='Original Variance')  
year_dframe['Log Variance'].plot(ax=ax[1], title='Log Variance')  
fig.tight_layout()

# %%
year_dframe['Logged First Difference'] = year_dframe['Natural Log'] - year_dframe['Natural Log'].shift()  
year_dframe['Logged First Difference'].plot(figsize=(16, 12))

# %%
year_dframe['Lag 1'] = year_dframe['Logged First Difference'].shift()  
year_dframe['Lag 2'] = year_dframe['Logged First Difference'].shift(1)  
#year_dframe['Lag 5'] = year_dframe['Logged First Difference'].shift(5)  
#year_dframe['Lag 30'] = year_dframe['Logged First Difference'].shift(30)

# %%
year_dframe
# Out:
#    Year  Values  First Difference  Natural Log  Original Variance  \
# 0  2008       1               NaN     0.000000                  0
# 1  2009       1                 0     0.000000                  0
# 2  2010       2                 1     0.693147                  0
# 3  2011       1                -1     0.000000                  0
# 4  2012       1                 0     0.000000                  0
# 5  2013       2                 1     0.693147                  0
# 6  2014       5                 3     1.609438                  0
#
#    Log Variance  Logged First Difference     Lag 1     Lag 2
# 0             0                      NaN       NaN       NaN
# 1             0                 0.000000       NaN       NaN
# 2             0                 0.693147  0.000000  0.000000
# 3             0                -0.693147  0.693147  0.693147
# 4             0                 0.000000 -0.693147 -0.693147
# 5             0                 0.693147  0.000000  0.000000
# ...

# %%
sb.jointplot('Logged First Difference', 'Lag 1', year_dframe, kind='reg', size=13)

# %%
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf

lag_correlations = acf(year_dframe['Logged First Difference'].iloc[1:])  
lag_partial_correlations = pacf(year_dframe['Logged First Difference'].iloc[1:])

# %%
fig, ax = plt.subplots(figsize=(16,12))  
ax.plot(lag_correlations, marker='o', linestyle='--')

# %%
date = ['2008-01-01','2009-01-01','2010-01-01','2011-01-01','2012-01-01','2013-01-01','2014-01-01',]
date = pd.Series(date)
log = pd.Series(year_dframe['Natural Log'].iloc[1:])
df = pd.concat([date,log],axis=1)
df.columns = ['date','Natural Log']
df['date'] = df['date'].convert_objects(convert_dates='coerce')
df = df.set_index(df.date)
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2008-01-01, ..., 2014-01-01]
# Length: 7, Freq: None, Timezone: None

# %%
model = sm.tsa.ARIMA(df['Natural Log'].iloc[1:], order=(0, 1,1))  
results = model.fit(disp=-1) 
df['Forecast'] = results.fittedvalues
df[['Natural Log', 'Forecast']].plot(figsize=(16, 12))

# %%
date = ['2008-01-01','2009-01-01','2010-01-01','2011-01-01','2012-01-01','2013-01-01','2014-01-01',]
date = pd.Series(date)
logfirst = pd.Series(year_dframe['Logged First Difference'].iloc[1:])
df2 = pd.concat([date,logfirst],axis=1)
df2.columns = ['date','Logged First Difference']
df2['date'] = df2['date'].convert_objects(convert_dates='coerce')
df2 = df2.set_index(df2.date)
df2.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2008-01-01, ..., 2014-01-01]
# Length: 7, Freq: None, Timezone: None

# %%
model2 = sm.tsa.ARIMA(df2['Logged First Difference'].iloc[1:], order=(0,0, 1))  
results2 = model2.fit(disp=-1)  
df2['Forecast'] = results.fittedvalues  
df2[['Logged First Difference', 'Forecast']].plot(figsize=(16, 12))

# %%
#df2

# %%
#from statsmodels.tsa.arima_process import arma_generate_sample
#from pandas import TimeSeries

# %%
date = ['2008-01-01','2009-01-01','2010-01-01','2011-01-01','2012-01-01','2013-01-01','2014-01-01',]
date = pd.Series(date)
logfirst = pd.Series(year_dframe['Values'].iloc[1:])
df2 = pd.concat([date,logfirst],axis=1)
df2.columns = ['date','Values']
df2['date'] = df2['date'].convert_objects(convert_dates='coerce')
df2 = df2.set_index(df2.date)
df2.index
df2
# Out:
#                  date  Values
# date
# 2008-01-01 2008-01-01     NaN
# 2009-01-01 2009-01-01       1
# 2010-01-01 2010-01-01       2
# 2011-01-01 2011-01-01       1
# 2012-01-01 2012-01-01       1
# 2013-01-01 2013-01-01       2
# 2014-01-01 2014-01-01       5
#
# [7 rows x 2 columns]

# %%
year_dframe['Values'].iloc[1:]#year_dframe
# Out:
# 1    1
# 2    2
# 3    1
# 4    1
# 5    2
# 6    5
# Name: Values, dtype: float64

# %%
#y = year_dframe.ix[:,:2]
#y = pd.TimeSeries(df2,index = df2.date)
#y

# %%
#arma_mod = sm.tsa.ARMA(df2, order=(0,0))

#arma_res = arma_mod.fit(disp=-1)#trend='nc', disp=-1)
#arma_res

# %%
#year_dframe['Forecast'] = arma_res.fittedvalues  
#year_dframe[['Values', 'Forecast']].plot(figsize=(8, 6))

# %%
#year_dframe['Forecast']

# %%
#import statsmodels.api as sm
#arima_model = sm.tsa.ARIMA(y, order=(1,0,0)).fit()

# %%
#from statsmodels.tsa.arima_process import arma_generate_sample
#from statsmodels.tsa.arima_process import arma_generate_sample

#np.random.seed(12345)

#arparams = np.array([.75, -.25])

#maparams = np.array([.65, .35])

# %%
#arparams = np.r_[1, -arparams]

#maparam = np.r_[1, maparams]

#nobs = 250

#y = arma_generate_sample(arparams, maparams, nobs)

# %%
#dates = sm.tsa.datetools.dates_from_range('1980m1', length=nobs)

#y = pd.TimeSeries(y, index=dates)

#arma_mod = sm.tsa.ARMA(y, order=(2, 2))

#arma_res = arma_mod.fit(trend='nc', disp=-1)
#arma_mod

# %%
#pd.TimeSeries(y, index=dates)

# %%
#data = sm.datasets.sunspots.load()

#endog = pd.TimeSeries(data.endog, index=dates)

# %%
import numpy as np
from sklearn import gaussian_process
def f(x):
    return x * np.sin(x)
X = np.atleast_2d([1., 3., 5., 6., 7., 8.]).T
y = f(X).ravel()
x = np.atleast_2d(np.linspace(0, 10, 1000)).T
gp = gaussian_process.GaussianProcess(theta0=1e-2, thetaL=1e-4, thetaU=1e-1)
gp.fit(X, y)
y_pred, sigma2_pred = gp.predict(x, eval_MSE=True)

# %%
plt.scatter(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-8aa872d7ea9d> in <module>()
# ----> 1 plt.scatter(X)
#
# TypeError: scatter() takes at least 2 arguments (1 given)

# %%
f(X)
# Out:
# array([[ 0.84147098],
#        [ 0.42336002],
#        [-4.79462137],
#        [-1.67649299],
#        [ 4.59890619],
#        [ 7.91486597]])

# %%
import numpy as np
from sklearn.gaussian_process import GaussianProcess
from matplotlib import pyplot as pl

np.random.seed(1)


def f(x):
    """The function to predict."""
    return x * np.sin(x)

#----------------------------------------------------------------------
#  First the noiseless case
X = np.atleast_2d([1., 3., 5., 6., 7., 8.]).T
#X = np.array(data05_cat.ix[1:,8]).T
#X = np.atleast_2d([1. ,2. ,1. ,1. ,2. ,5.]).T
# Observations
y = f(X).ravel()

# Mesh the input space for evaluations of the real function, the prediction and
# its MSE
x = np.atleast_2d(np.linspace(0, 10, 1000)).T

# Instanciate a Gaussian Process model
gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1e-1,
                     random_start=100)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, MSE = gp.predict(x, eval_MSE=True)
sigma = np.sqrt(MSE)

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
fig = pl.figure()
pl.plot(x, f(x), 'r:', label=u'$f(x) = x\,\sin(x)$')
pl.plot(X, y, 'r.', markersize=10, label=u'Observations')
pl.plot(x, y_pred, 'b-', label=u'Prediction')
pl.fill(np.concatenate([x, x[::-1]]),
        np.concatenate([y_pred - 1.9600 * sigma,
                       (y_pred + 1.9600 * sigma)[::-1]]),
        alpha=.5, fc='b', ec='None', label='95% confidence interval')
pl.xlabel('$x$')
pl.ylabel('$f(x)$')
pl.ylim(-10, 20)
pl.legend(loc='upper left')

#----------------------------------------------------------------------
# now the noisy case
X = np.linspace(0.1, 9.9, 20)
X = np.atleast_2d(X).T

# Observations and noise
y = f(X).ravel()
dy = 0.5 + 1.0 * np.random.random(y.shape)
noise = np.random.normal(0, dy)
y += noise

# Mesh the input space for evaluations of the real function, the prediction and
# its MSE
x = np.atleast_2d(np.linspace(0, 10, 1000)).T

# Instanciate a Gaussian Process model
gp = GaussianProcess(corr='squared_exponential', theta0=1e-1,
                     thetaL=1e-3, thetaU=1,
                     nugget=(dy / y) ** 2,
                     random_start=100)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, MSE = gp.predict(x, eval_MSE=True)
sigma = np.sqrt(MSE)

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
fig = pl.figure()
pl.plot(x, f(x), 'r:', label=u'$f(x) = x\,\sin(x)$')
pl.errorbar(X.ravel(), y, dy, fmt='r.', markersize=10, label=u'Observations')
pl.plot(x, y_pred, 'b-', label=u'Prediction')
pl.fill(np.concatenate([x, x[::-1]]),
        np.concatenate([y_pred - 1.9600 * sigma,
                       (y_pred + 1.9600 * sigma)[::-1]]),
        alpha=.5, fc='b', ec='None', label='95% confidence interval')
pl.xlabel('$x$')
pl.ylabel('$f(x)$')
pl.ylim(-10, 20)
pl.legend(loc='upper left')

pl.show()

# %%
new = 'app/static/Today Map ' + 'Bushwick' + '.png'

# %%
new
# Out:
# 'app/static/Today Map Bushwick.png'

# %%
new[4:]
# Out:
# 'static/Today Map Bushwick.png'

# %%
data05_cat['Restaurant Wine']
# Out:
# 0     22
# 1      5
# 2      3
# 3      1
# 4      6
# 5      8
# 6      2
# 7      2
# 8      2
# 9      0
# 10     1
# 11     2
# 12     9
# 13     0
# 14     6
# 15     7
# Name: Restaurant Wine, dtype: float64

# %%
data06_cat['Restaurant Wine']
# Out:
# 0     16
# 1      2
# 2      1
# 3      2
# 4      4
# 5      6
# 6      0
# 7      3
# 8      4
# 9      6
# 10     1
# 11     0
# 12    15
# 13     3
# 14     5
# 15    10
# Name: Restaurant Wine, dtype: float64

# %%
sns.regplot(x=data05_cat.ix[1:,8], y=data06_cat.ix[1:,8]);

# %%
np.array(data05_cat.ix[1:,8])
# Out:
# array([ 5.,  3.,  1.,  6.,  8.,  2.,  2.,  2.,  0.,  1.,  2.,  9.,  0.,
#         6.,  7.])

# %%
from statsmodels.tsa.ar_model import AR

# %%
ar_mod = AR(np.array(data05_cat.ix[1:,8]))
ar_res = ar_mod.fit(1)
ar_res.predict(4)
# Out:
# array([ 3.34553629,  3.22864483,  3.5793192 ,  3.5793192 ,  3.5793192 ,
#         3.69621066,  3.63776493,  3.5793192 ,  3.1701991 ,  3.69621066,
#         3.34553629])

# %%
ar_res.params
# Out:
# array([ 3.69621066, -0.05844573])

# %%
len(ar_res.params)
# Out:
# 2

# %%
np.array(data05_cat['Restaurant Wine'])
# Out:
# array([ 22.,   5.,   3.,   1.,   6.,   8.,   2.,   2.,   2.,   0.,   1.,
#          2.,   9.,   0.,   6.,   7.])

# %%
wine05 = pd.Series(data05_cat['Restaurant Wine'])
wine06 = pd.Series(data06_cat['Restaurant Wine'])
wine07 = pd.Series(data07_cat['Restaurant Wine'])
wine08 = pd.Series(data08_cat['Restaurant Wine'])
wine09 = pd.Series(data09_cat['Restaurant Wine'])
wine10 = pd.Series(data10_cat['Restaurant Wine'])
wine11 = pd.Series(data11_cat['Restaurant Wine'])
wine12 = pd.Series(data12_cat['Restaurant Wine'])
wine13 = pd.Series(data13_cat['Restaurant Wine'])
wine14 = pd.Series(data14_cat['Restaurant Wine'])
wine15 = pd.Series(data15_cat['Restaurant Wine'])

# %%
pd.concat([wine05,wine06,wine07,wine08,wine09,wine10,wine11,wine12,wine13,wine14],axis=1)
# Out:
#     Restaurant Wine  Restaurant Wine  Restaurant Wine  Restaurant Wine  \
# 0                22               16               21               19
# 1                 5                2                4                6
# 2                 3                1                1                2
# 3                 1                2                1                0
# 4                 6                4                8                2
# 5                 8                6                5                7
# 6                 2                0                0                1
# 7                 2                3                2                2
# 8                 2                4                1                2
# 9                 0                6                4                3
# 10                1                1                2                1
# 11                2                0                2                3
# ...

# %%
import csv

WineDataFrame = pd.concat([wine05,wine06,wine07,wine08,wine09,wine10,wine11,wine12,wine13,wine14],axis=1)
WineDataFrame.to_csv("TimeSeriesData/WineDataFrame.csv")
